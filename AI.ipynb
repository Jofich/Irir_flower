# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Iris_data = pd.read_csv("bezdekIris.csv",header=None)

# %%
Iris_data.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
#меняем имена columns 
Iris_data.rename(columns = {0: 'sepal length(cm)', 1: 'sepal width(cm)', 2: 'petal length(cm)', 3: 'petal width(cm)',4: "class"}, inplace = True )

# %%
Iris_data.head()
# Out:
#    sepal length(cm)  sepal width(cm)  petal length(cm)  petal width(cm)  \
# 0               5.1              3.5               1.4              0.2
# 1               4.9              3.0               1.4              0.2
# 2               4.7              3.2               1.3              0.2
# 3               4.6              3.1               1.5              0.2
# 4               5.0              3.6               1.4              0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
Iris_data.shape
# Out:
# (150, 5)

# %%
Iris_data.describe()
# Out:
#        sepal length(cm)  sepal width(cm)  petal length(cm)  petal width(cm)
# count        150.000000       150.000000        150.000000       150.000000
# mean           5.843333         3.057333          3.758000         1.199333
# std            0.828066         0.435866          1.765298         0.762238
# min            4.300000         2.000000          1.000000         0.100000
# 25%            5.100000         2.800000          1.600000         0.300000
# 50%            5.800000         3.000000          4.350000         1.300000
# 75%            6.400000         3.300000          5.100000         1.800000
# max            7.900000         4.400000          6.900000         2.500000

# %%
Iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sepal length(cm)  150 non-null    float64
#  1   sepal width(cm)   150 non-null    float64
#  2   petal length(cm)  150 non-null    float64
#  3   petal width(cm)   150 non-null    float64
#  4   class             150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
Iris_data['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
Iris_data.isnull().values.any()
#пропусков нету,по этому никаких дополнительных действий с датасетом проводить не нужно
# Out:
# False

# %%
sns.pairplot(Iris_data,hue ="class")

# %%
#хорошо заметно,что класс Iris-setosa характерно отличается от двух других
#могу предположить,что
